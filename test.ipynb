# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heroes.csv')
df.describe()
# Out:
#         feature1   feature2   feature3   feature4   feature5   feature6  \
# count  98.000000  98.000000  98.000000  98.000000  98.000000  98.000000
# mean    0.854592   3.277551   0.581633   0.954082   1.328571   1.278061
# std     1.365029   5.475825   0.185754   1.625881   2.703377   0.942197
# min     0.250000   0.170000   0.500000   0.250000   0.200000   0.250000
# 25%     0.250000   0.330000   0.500000   0.250000   0.200000   0.500000
# 50%     0.250000   1.500000   0.500000   0.500000   0.200000   0.500000
# 75%     0.500000   3.920000   0.500000   0.500000   1.800000   2.250000
# max     7.000000  21.330000   1.000000   7.000000  13.000000   2.250000
#
#         feature7    cluster
# count  98.000000  98.000000
# mean    9.632245   1.469388
# std     8.955473   1.159489
# min     0.170000   0.000000
# 25%     1.500000   1.000000
# 50%     4.915000   1.000000
# 75%    21.000000   3.000000
# max    22.830000   4.000000

# %%
df = df.drop(columns = ['vector','cluster','name'])
df.head()
colum = ['feature1',
 'feature2',
 'feature3',
 'feature4',
 'feature5',
 'feature6',
 'feature7']

# %%
df.columns.tolist()
# Out:
# ['feature1',
#  'feature2',
#  'feature3',
#  'feature4',
#  'feature5',
#  'feature6',
#  'feature7']

# %%
sns.pairplot(df[colum], hue='feature2', palette='Set1')
plt.show()
